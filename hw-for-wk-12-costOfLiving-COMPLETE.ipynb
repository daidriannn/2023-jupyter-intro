# %% [markdown]
# # Visual Exploration
#
# #### You have a <a href = "https://docs.google.com/spreadsheets/d/1CYdbCfj0aF-bKNJ3lIPe6_rKkWT-IlCMXxNQtjkiD34/edit?usp=sharing">spreadsheet</a> that has the price of monthly cable bills, median income, and social security percentage increases. The data is from 1995 to 2022.
#
# #### Create a line chart that hopefully reveals a trend between cable prices, median income and social security increases. Make the cable bill red; median income blue, and social security gray.
#
# #### What would be your "thesis" based on your findings?
#
# **Note about social security increases:**
#
# Each year the U.S. government increases the amount of social security retired people receive. That increase is based on the annual inflation rate  and the political climate (or party in control). I have indexed the numbers so 1995 is 100, and each year after that the number reflects a percentage increase since 1995. So between 1995 at 100 and 1996 at 102.6 reflects a 2.6 percent increase. And between 1995 and 1997 reflects a 5.6 percent increase.

# %%
import pandas as pd

# %%
df_raw = pd.read_csv("cable-bill-only - Sheet1.csv")
df_raw
# Out:
#     Avg. cable bill  Median household income  \
# 0             22.35                      NaN
# 1             23.28                      NaN
# 2             26.31                      NaN
# 3             27.88                      NaN
# 4             28.94                      NaN
# 5             31.22                      NaN
# 6             33.75                      NaN
# 7             36.47                      NaN
# 8             38.95                      NaN
# 9             41.04                      NaN
# 10            43.04                      NaN
# 11            43.26                      NaN
# 12            47.27                      NaN
# 13            49.65                      NaN
# 14            52.37                      NaN
# 15            54.44                      NaN
# 16            57.46                      NaN
# 17            61.63                      NaN
# 18            69.18                      NaN
# 19            71.45                      NaN
# 20            78.42                      NaN
# 21           150.98                      NaN
# 22           168.49                      NaN
# 23           199.99                      NaN
# 24           210.84                      NaN
# 25           217.42                      NaN
# 26           231.10                      NaN
# 27           251.48                      NaN
#
#     Social Security cost-of-living adjustment
# 0                                       100.0
# 1                                       102.6
# 2                                       105.6
# 3                                       107.8
# 4                                       109.2
# 5                                       111.9
# 6                                       115.8
# 7                                       118.9
# 8                                       120.5
# 9                                       123.0
# 10                                      126.4
# 11                                      131.6
# 12                                      135.9
# 13                                      139.0
# 14                                      147.1
# 15                                      147.1
# 16                                      147.1
# 17                                      152.4
# 18                                      155.0
# 19                                      157.3
# 20                                      159.0
# 21                                      159.0
# 22                                      159.3
# 23                                      161.3
# 24                                      164.1
# 25                                      165.7
# 26                                      167.0
# 27                                      172.9

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Avg. cable bill                            28 non-null     float64
#  1   Median household income                    0 non-null      float64
#  2   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(3)
# memory usage: 800.0 bytes

# %%
df_raw.columns
# Out:
# Index(['Avg. cable bill', 'Median household income',
#        'Social Security cost-of-living adjustment'],
#       dtype='object')

# %%
df = df_raw[['Avg. cable bill', 'Median household income','Social Security cost-of-living adjustment']].copy()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cq/msbbvsx52h32n9sgh6m1k0740000gn/T/ipykernel_35289/2359108098.py in <module>
# ----> 1 df = df_raw[['Year','Avg. cable bill', 'Median household income','Social Security cost-of-living adjustment']].copy()
#       2 df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859             raise KeyError(f"{not_found} not in index")
#    5860
#    5861     @overload
#
# KeyError: "['Year'] not in index"

# %%
df.drop(0).reset_index(drop = True)
# Out:
#     Avg. cable bill  Median household income  \
# 0             23.28                      NaN
# 1             26.31                      NaN
# 2             27.88                      NaN
# 3             28.94                      NaN
# 4             31.22                      NaN
# 5             33.75                      NaN
# 6             36.47                      NaN
# 7             38.95                      NaN
# 8             41.04                      NaN
# 9             43.04                      NaN
# 10            43.26                      NaN
# 11            47.27                      NaN
# 12            49.65                      NaN
# 13            52.37                      NaN
# 14            54.44                      NaN
# 15            57.46                      NaN
# 16            61.63                      NaN
# 17            69.18                      NaN
# 18            71.45                      NaN
# 19            78.42                      NaN
# 20           150.98                      NaN
# 21           168.49                      NaN
# 22           199.99                      NaN
# 23           210.84                      NaN
# 24           217.42                      NaN
# 25           231.10                      NaN
# 26           251.48                      NaN
#
#     Social Security cost-of-living adjustment
# 0                                       102.6
# 1                                       105.6
# 2                                       107.8
# 3                                       109.2
# 4                                       111.9
# 5                                       115.8
# 6                                       118.9
# 7                                       120.5
# 8                                       123.0
# 9                                       126.4
# 10                                      131.6
# 11                                      135.9
# 12                                      139.0
# 13                                      147.1
# 14                                      147.1
# 15                                      147.1
# 16                                      152.4
# 17                                      155.0
# 18                                      157.3
# 19                                      159.0
# 20                                      159.0
# 21                                      159.3
# 22                                      161.3
# 23                                      164.1
# 24                                      165.7
# 25                                      167.0
# 26                                      172.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Avg. cable bill                            28 non-null     float64
#  1   Median household income                    0 non-null      float64
#  2   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(3)
# memory usage: 800.0 bytes

# %%
df["Median household income"] = pd.to_numeric(df["Median household income"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Avg. cable bill                            28 non-null     float64
#  1   Median household income                    0 non-null      float64
#  2   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(3)
# memory usage: 800.0 bytes

# %%
df["Social Security cost-of-living adjustment"] = pd.to_numeric(df["Social Security cost-of-living adjustment"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Avg. cable bill                            28 non-null     float64
#  1   Median household income                    0 non-null      float64
#  2   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(3)
# memory usage: 800.0 bytes

# %%
df["Avg. cable bill"] = pd.to_numeric(df["Avg. cable bill"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Avg. cable bill                            28 non-null     float64
#  1   Median household income                    0 non-null      float64
#  2   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(3)
# memory usage: 800.0 bytes

# %%
df
# Out:
#     Avg. cable bill  Median household income  \
# 0             22.35                      NaN
# 1             23.28                      NaN
# 2             26.31                      NaN
# 3             27.88                      NaN
# 4             28.94                      NaN
# 5             31.22                      NaN
# 6             33.75                      NaN
# 7             36.47                      NaN
# 8             38.95                      NaN
# 9             41.04                      NaN
# 10            43.04                      NaN
# 11            43.26                      NaN
# 12            47.27                      NaN
# 13            49.65                      NaN
# 14            52.37                      NaN
# 15            54.44                      NaN
# 16            57.46                      NaN
# 17            61.63                      NaN
# 18            69.18                      NaN
# 19            71.45                      NaN
# 20            78.42                      NaN
# 21           150.98                      NaN
# 22           168.49                      NaN
# 23           199.99                      NaN
# 24           210.84                      NaN
# 25           217.42                      NaN
# 26           231.10                      NaN
# 27           251.48                      NaN
#
#     Social Security cost-of-living adjustment
# 0                                       100.0
# 1                                       102.6
# 2                                       105.6
# 3                                       107.8
# 4                                       109.2
# 5                                       111.9
# 6                                       115.8
# 7                                       118.9
# 8                                       120.5
# 9                                       123.0
# 10                                      126.4
# 11                                      131.6
# 12                                      135.9
# 13                                      139.0
# 14                                      147.1
# 15                                      147.1
# 16                                      147.1
# 17                                      152.4
# 18                                      155.0
# 19                                      157.3
# 20                                      159.0
# 21                                      159.0
# 22                                      159.3
# 23                                      161.3
# 24                                      164.1
# 25                                      165.7
# 26                                      167.0
# 27                                      172.9

# %%
df.to_csv("cable-bill-only - Sheet1.csv" , index = False, encoding = "UTF8")

# %%
avg_cable = df["Avg. cable bill"].iat[1]
avg_cable
# Out:
# 23.28

# %%
df["cable_pct_chg"] = \
((df["Avg. cable bill"] - avg_cable) / avg_cable) * 100

df
# Out:
#     Avg. cable bill  Median household income  \
# 0             22.35                      NaN
# 1             23.28                      NaN
# 2             26.31                      NaN
# 3             27.88                      NaN
# 4             28.94                      NaN
# 5             31.22                      NaN
# 6             33.75                      NaN
# 7             36.47                      NaN
# 8             38.95                      NaN
# 9             41.04                      NaN
# 10            43.04                      NaN
# 11            43.26                      NaN
# 12            47.27                      NaN
# 13            49.65                      NaN
# 14            52.37                      NaN
# 15            54.44                      NaN
# 16            57.46                      NaN
# 17            61.63                      NaN
# 18            69.18                      NaN
# 19            71.45                      NaN
# 20            78.42                      NaN
# 21           150.98                      NaN
# 22           168.49                      NaN
# 23           199.99                      NaN
# 24           210.84                      NaN
# 25           217.42                      NaN
# 26           231.10                      NaN
# 27           251.48                      NaN
#
#     Social Security cost-of-living adjustment  cable_pct_chg
# 0                                       100.0      -3.994845
# 1                                       102.6       0.000000
# 2                                       105.6      13.015464
# 3                                       107.8      19.759450
# 4                                       109.2      24.312715
# 5                                       111.9      34.106529
# 6                                       115.8      44.974227
# 7                                       118.9      56.658076
# 8                                       120.5      67.310997
# 9                                       123.0      76.288660
# 10                                      126.4      84.879725
# 11                                      131.6      85.824742
# 12                                      135.9     103.049828
# 13                                      139.0     113.273196
# 14                                      147.1     124.957045
# 15                                      147.1     133.848797
# 16                                      147.1     146.821306
# 17                                      152.4     164.733677
# 18                                      155.0     197.164948
# 19                                      157.3     206.915808
# 20                                      159.0     236.855670
# 21                                      159.0     548.539519
# 22                                      159.3     623.754296
# 23                                      161.3     759.063574
# 24                                      164.1     805.670103
# 25                                      165.7     833.934708
# 26                                      167.0     892.697595
# 27                                      172.9     980.240550

# %%
med_income = df["Median household income"].iat[1]
med_income
# Out:
# nan

# %%
df["medincome_pct_chg"] = \
((df["Median household income"] - med_income) / med_income) * 100

df
# Out:
#     Avg. cable bill  Median household income  \
# 0             22.35                      NaN
# 1             23.28                      NaN
# 2             26.31                      NaN
# 3             27.88                      NaN
# 4             28.94                      NaN
# 5             31.22                      NaN
# 6             33.75                      NaN
# 7             36.47                      NaN
# 8             38.95                      NaN
# 9             41.04                      NaN
# 10            43.04                      NaN
# 11            43.26                      NaN
# 12            47.27                      NaN
# 13            49.65                      NaN
# 14            52.37                      NaN
# 15            54.44                      NaN
# 16            57.46                      NaN
# 17            61.63                      NaN
# 18            69.18                      NaN
# 19            71.45                      NaN
# 20            78.42                      NaN
# 21           150.98                      NaN
# 22           168.49                      NaN
# 23           199.99                      NaN
# 24           210.84                      NaN
# 25           217.42                      NaN
# 26           231.10                      NaN
# 27           251.48                      NaN
#
#     Social Security cost-of-living adjustment  cable_pct_chg  \
# 0                                       100.0      -3.994845
# 1                                       102.6       0.000000
# 2                                       105.6      13.015464
# 3                                       107.8      19.759450
# 4                                       109.2      24.312715
# 5                                       111.9      34.106529
# 6                                       115.8      44.974227
# 7                                       118.9      56.658076
# 8                                       120.5      67.310997
# 9                                       123.0      76.288660
# 10                                      126.4      84.879725
# 11                                      131.6      85.824742
# 12                                      135.9     103.049828
# 13                                      139.0     113.273196
# 14                                      147.1     124.957045
# 15                                      147.1     133.848797
# 16                                      147.1     146.821306
# 17                                      152.4     164.733677
# 18                                      155.0     197.164948
# 19                                      157.3     206.915808
# 20                                      159.0     236.855670
# 21                                      159.0     548.539519
# 22                                      159.3     623.754296
# 23                                      161.3     759.063574
# 24                                      164.1     805.670103
# 25                                      165.7     833.934708
# 26                                      167.0     892.697595
# 27                                      172.9     980.240550
#
#     medincome_pct_chg
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN

# %%
ss_cola = df["Social Security cost-of-living adjustment"].iat[1]
ss_cola
# Out:
# 102.6

# %%
df["sscola_pct_chg"] = \
((df["Social Security cost-of-living adjustment"] - avg_cable) / avg_cable) * 100

df
# Out:
#     Avg. cable bill  Median household income  \
# 0             22.35                      NaN
# 1             23.28                      NaN
# 2             26.31                      NaN
# 3             27.88                      NaN
# 4             28.94                      NaN
# 5             31.22                      NaN
# 6             33.75                      NaN
# 7             36.47                      NaN
# 8             38.95                      NaN
# 9             41.04                      NaN
# 10            43.04                      NaN
# 11            43.26                      NaN
# 12            47.27                      NaN
# 13            49.65                      NaN
# 14            52.37                      NaN
# 15            54.44                      NaN
# 16            57.46                      NaN
# 17            61.63                      NaN
# 18            69.18                      NaN
# 19            71.45                      NaN
# 20            78.42                      NaN
# 21           150.98                      NaN
# 22           168.49                      NaN
# 23           199.99                      NaN
# 24           210.84                      NaN
# 25           217.42                      NaN
# 26           231.10                      NaN
# 27           251.48                      NaN
#
#     Social Security cost-of-living adjustment  cable_pct_chg  \
# 0                                       100.0      -3.994845
# 1                                       102.6       0.000000
# 2                                       105.6      13.015464
# 3                                       107.8      19.759450
# 4                                       109.2      24.312715
# 5                                       111.9      34.106529
# 6                                       115.8      44.974227
# 7                                       118.9      56.658076
# 8                                       120.5      67.310997
# 9                                       123.0      76.288660
# 10                                      126.4      84.879725
# 11                                      131.6      85.824742
# 12                                      135.9     103.049828
# 13                                      139.0     113.273196
# 14                                      147.1     124.957045
# 15                                      147.1     133.848797
# 16                                      147.1     146.821306
# 17                                      152.4     164.733677
# 18                                      155.0     197.164948
# 19                                      157.3     206.915808
# 20                                      159.0     236.855670
# 21                                      159.0     548.539519
# 22                                      159.3     623.754296
# 23                                      161.3     759.063574
# 24                                      164.1     805.670103
# 25                                      165.7     833.934708
# 26                                      167.0     892.697595
# 27                                      172.9     980.240550
#
#     medincome_pct_chg  sscola_pct_chg
# 0                 NaN      329.553265
# 1                 NaN      340.721649
# 2                 NaN      353.608247
# 3                 NaN      363.058419
# 4                 NaN      369.072165
# 5                 NaN      380.670103
# 6                 NaN      397.422680
# 7                 NaN      410.738832
# 8                 NaN      417.611684
# 9                 NaN      428.350515
# 10                NaN      442.955326
# 11                NaN      465.292096
# 12                NaN      483.762887
# 13                NaN      497.079038
# 14                NaN      531.872852
# 15                NaN      531.872852
# 16                NaN      531.872852
# 17                NaN      554.639175
# 18                NaN      565.807560
# 19                NaN      575.687285
# 20                NaN      582.989691
# 21                NaN      582.989691
# 22                NaN      584.278351
# 23                NaN      592.869416
# 24                NaN      604.896907
# 25                NaN      611.769759
# 26                NaN      617.353952
# 27                NaN      642.697595

# %%
df.plot(x= "Avg. cable bill",
       y = ["cable_pct_chg", "medincome_pct_chg","sscola_pct_chg"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/cq/msbbvsx52h32n9sgh6m1k0740000gn/T/ipykernel_35289/2429294358.py in <module>
# ----> 1 df.plot(x= "Avg. cable bill",
#       2        y = ["cable_pct_chg", "medincome_pct_chg","sscola_pct_chg"])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     956
#     957                 # don't overwrite
# --> 958                 data = data[y].copy()
#     959
#     960                 if isinstance(data, ABCSeries):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['cable_pct_chg', 'medincome_pct_chg', 'sscola_pct_chg'], dtype='object')] are in the [columns]"

# %%
df.plot(x = "Avg. cable bill",
       y = ["cable_pct_chg", "medincome_pct_chg","sscola_pct_chg"],
       title = "Trend: Cable; Median Income; Social Security Increases",
        style = {"cable_pct_chg": "red",
                 "medincome_pct_chg": "blue"
                 "sscola_pct_chg": "gray"
                })
